# %%
import numpy as np

# %%
neg_LpD_inv = np.array([[-1/4,0,0],[1/16,-1/4,0],[-1/32,1/8,-1/2]])
neg_LpD_inv
# Out:
# array([[-0.25   ,  0.     ,  0.     ],
#        [ 0.0625 , -0.25   ,  0.     ],
#        [-0.03125,  0.125  , -0.5    ]])

# %%
LpD_inv = np.array([[1/4,0,0],[-1/16,1/4,0],[1/32,-1/8,1/2]])
LpD_inv
# Out:
# array([[ 0.25   ,  0.     ,  0.     ],
#        [-0.0625 ,  0.25   ,  0.     ],
#        [ 0.03125, -0.125  ,  0.5    ]])

# %%
U = np.array([[0,2,1],[0,0,3],[0,0,0]])
U
# Out:
# array([[0, 2, 1],
#        [0, 0, 3],
#        [0, 0, 0]])

# %%
b = np.array([1,0,0])

# %%
np.matmul(neg_LpD_inv,U)
# Out:
# array([[ 0.     , -0.5    , -0.25   ],
#        [ 0.     ,  0.125  , -0.6875 ],
#        [ 0.     , -0.0625 ,  0.34375]])

# %%
-11/16
# Out:
# -0.6875

# %%
11/32
# Out:
# 0.34375

# %%
np.matmul(LpD_inv,b)
# Out:
# array([ 0.25   , -0.0625 ,  0.03125])

# %%
512/128
# Out:
# 4.0

# %%
512/16
# Out:
# 32.0

# %%
1024/32
# Out:
# 32.0

# %%
np.log(1/1000*12/16)/np.log(13/16)
# Out:
# 34.65353190190371
